# %% [markdown]
# # DSCI 100: Introduction to Data Science
# ## Tutorial 4: Effective Data Visualization Class Activity

# %% [markdown]
# Create a new R Jupyter notebook.

# %% [markdown]
# Load the `tidyverse` and `repr` libraries

# %%
options(repr.matrix.max.rows = 6)

# your code here
library(tidyverse)
library(repr)

# %% [markdown]
# We are interested in the distribution of the prices of diamonds which are **greater than or equal to 1 carat**. We will visualize this distribution with a **histogram**, which has **$500** intervals.
#
# First, take a look at the `diamonds` dataset and filter the data so we only have diamonds **greater than or equal to 1 carat**.

# %%
# your code here
diamonds
diamonds_edit <- diamonds %>%
    filter(carat>=1)
diamonds_edit
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# ⋮     ⋮     ⋮         ⋮     ⋮       ⋮     ⋮     ⋮     ⋮    ⋮    ⋮
# 53938 0.70  Very Good D     SI1     62.8  60    2757  5.66 5.68 3.56
# 53939 0.86  Premium   H     SI2     61.0  58    2757  6.15 6.12 3.74
# 53940 0.75  Ideal     D     SI2     62.2  55    2757  5.83 5.87 3.64
#       carat cut       color clarity depth table price x    y    z
# 1     1.17  Very Good J     I1      60.2  61    2774  6.83 6.90 4.13
# 2     1.01  Premium   F     I1      61.8  60    2781  6.39 6.36 3.94
# 3     1.01  Fair      E     I1      64.5  58    2788  6.29 6.21 4.03
# ⋮     ⋮     ⋮         ⋮     ⋮       ⋮     ⋮     ⋮     ⋮    ⋮    ⋮
# 19058 1.04  Very Good I     I1      61.6  61    2745  6.45 6.47 3.98
# 19059 1.04  Fair      G     SI2     65.2  57    2745  6.25 6.23 4.07
# 19060 1.02  Good      H     I1      64.3  63    2751  6.28 6.23 4.02

# %% [markdown]
# Now, make a **histogram** where we count the distribution of prices of diamonds which are **greater than or equal to 1 carat** in intervals of **$500**. Also, don't forget to size the plot appropriately and name the axes and legend.
#
# Here is a hint taken from https://rstudio.com/resources/cheatsheets/
#
# I recommend everyone take a look at this as they have cheat sheets for other libraries we use.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# your code here
options(repr.plot.height= 7, repr.plot.width= 10)
dplot <- ggplot(diamonds_edit, aes(price))+
    geom_histogram(binwidth=500)+
    xlab("Price(USD)")+
    ylab("Number of Diamonds")+
    ggtitle("Distribution of Diamonds By Price")+
    theme(text=element_text(size=20))
dplot
# Out:
# plot without title

# %% [markdown]
# Now, what if we are interested in seeing the number of diamonds for each type of cut in each interval?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hint: Look back at Worksheet_04 Questions 2.9.3 and 2.9.4 and see how they managed to add colour to distinguish the restaurant names

# %%
# your code here
options(repr.plot.height= 7, repr.plot.width= 10)
dplot <- ggplot(diamonds_edit, aes(price, fill=cut))+
    geom_histogram(binwidth=500)+
    xlab("Price(USD)")+
    ylab("Number of Diamonds")+
    labs(fill= "Cut")+
    ggtitle("Distribution of Diamonds By Price")+
    theme(text=element_text(size=20))
dplot
# Out:
# plot without title

# %% [markdown]
# Notice that when looking at the number of diamonds for each cut, it doesn't look right when comparing with our y-axis. This is because the histogram takes the total number of diamonds rather than making separate histograms for each cut. So what if we want to see more clearly the distribution for each cut individually?
#
# We can make a line plot out of our histogram by using the `geom_freqpoly` function:

# %%
options(repr.plot.height = 7, repr.plot.width = 10)
d2plot <- ggplot(diamonds_edit, aes(price, color = cut)) +
              geom_freqpoly(binwidth = 500, size = 1.5)  +
              theme(text = element_text(size = 20))+
              labs(color = "Cut", x = 'Price (USD)', y = 'Count')
d2plot
# Out:
# plot without title
